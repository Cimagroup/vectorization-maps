# %%
import numpy as np
import matplotlib.pyplot as plt
import persistence_curves as pc

# %% [markdown]
# We are testing the curves defined in the persistence_curve script: the betti curve, the persistet entropy curve and the normalized lifespan curve.

# %% [markdown]
# We define the list of barcodes pds

# %%
pd1 = np.array([[159.0, 235.0],
               [139.0, 213.0],
               [184.0, 238.0],
               [119.0, 165.0],
               [101.0, 136.0],
               [ 93.0, 124.0],
               [ 73.0,  91.0],
               [ 55.0,  69.0],
               [206.0, 219.0],
               [158.0, 170.0],
               [221.0, 232.0],
               [161.0, 172.0],
               [206.0, 217.0],
               [208.0, 218.0],
               [208.0, 217.0],
               [ 83.0,  91.0],
               [117.0, 124.0],
               [226.0, 232.0],
               [158.0, 164.0],
               [153.0, 159.0],
               [202.0, 207.0],
               [222.0, 227.0],
               [210.0, 214.0],
               [ 58.0,  62.0],
               [ 67.0,  71.0],
               [158.0, 162.0],
               [ 95.0,  98.0],
               [177.0, 180.0],
               [220.0, 223.0],
               [226.0, 229.0],
               [208.0, 210.0],
               [211.0, 213.0],
               [165.0, 167.0],
               [211.0, 213.0],
               [172.0, 174.0],
               [211.0, 213.0],
               [165.0, 167.0],
               [209.0, 210.0],
               [ 85.0,  86.0],
               [170.0, 171.0],
               [102.0, 103.0],
               [212.0, 213.0],
               [ 68.0,  69.0],
               [ 66.0,  67.0],
               [222.0, 223.0],
               [229.0, 230.0],
               [230.0, 231.0]])

# %%
pd2 =np.array([[ 20.,  58.],
               [149., 185.],
               [ 98., 124.],
               [222., 243.],
               [ 44.,  65.],
               [ 92., 112.],
               [160., 180.],
               [218., 236.],
               [203., 220.],
               [174., 191.],
               [ 36.,  53.],
               [108., 123.],
               [182., 197.],
               [230., 242.],
               [139., 150.],
               [212., 223.],
               [220., 230.],
               [132., 141.],
               [117., 126.],
               [226., 234.],
               [190., 198.],
               [172., 179.],
               [213., 220.],
               [124., 130.],
               [178., 184.],
               [114., 120.],
               [218., 224.],
               [238., 243.],
               [236., 241.],
               [124., 129.],
               [202., 207.],
               [115., 119.],
               [177., 181.],
               [176., 180.],
               [220., 224.],
               [204., 208.],
               [ 95.,  98.],
               [186., 189.],
               [228., 230.],
               [215., 217.],
               [163., 164.],
               [215., 216.],
               [193., 194.],
               [163., 164.],
               [215., 216.],
               [229., 230.],
               [229., 230.],
               [218., 219.],
               [217., 218.],
               [219., 220.],
               [180., 181.]])

# %%
pds = [pd1, pd2]

# %% [markdown]
# We calculate the corresponding curve to each of the barcode and plot an example of each.

# %%
ent = pc.Entropy(mode='vector')
pds_ent = ent.fit_transform(pds)
pds_ent = ent.fit_transform(pds)

# %%
plt.plot(pds_ent[1])
plt.title('Entropy')
# Out:
# Text(0.5, 1.0, 'Entropy')

# %%
btt = pc.BettiCurve()
pds_btt = btt.fit_transform(pds)
pds_btt = btt.fit_transform(pds)

# %%
plt.plot(pds_btt[1])
plt.title('Betti')
# Out:
# Text(0.5, 1.0, 'Betti')

# %%
lsp = pc.Lifespan()
pds_lsp = lsp.fit_transform(pds)
pds_lsp = lsp.fit_transform(pds)

# %%
plt.plot(pds_lsp[1])
plt.title('Lifespan')
# Out:
# Text(0.5, 1.0, 'Lifespan')
