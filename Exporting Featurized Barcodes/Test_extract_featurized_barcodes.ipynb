# %% [markdown]
# # Testing All Feaurized Barcodes

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
import extract_featurized_barcodes as ex

# %%
img = cv2.imread("1.pgm",0)

# %%
plt.imshow(img)

# %%
img = cv2.resize(img, dsize=(32, 32), interpolation=cv2.INTER_CUBIC)

# %%
img = np.ndarray.flatten(img)

# %%
pds = ex.GetCubicalComplexPDs(img, [32, 32])

# %%
persStatsFeat = [ex.GetPersStats(pd) for pd in pds]
persImageFeat = [ex.GetPersImageFeature(pd, [30, 30]) for pd in pds]
persLandscapeFeat = [ex.GetPersLandscapeFeature(pd, 100) for pd in pds]
bettiCurveFeat = [ex.GetBettiCurveFeature(pd, 100) for pd in pds]
persSilhouetteFeat = [ex.GetPersSilhouetteFeature(pd) for pd in pds]
topologicalVectorFeat = [ex.GetTopologicalVectorFeature(pd) for pd in pds]
tropicalCoordinatesFeat = [ex.GetPersTropicalCoordinatesFeature(pd, r=28) for pd in pds]

quantiser = KMeans(n_clusters=2, random_state=202006)
atolFeat = [ex.GetAtolFeature(pd, quantiser) for pd in pds]

complexPolynomialFeat = [ex.GetComplexPolynomialFeature(pd) for pd in pds]

persEntropyFeat = ex.GetPersEntropyFeature(pds)
carlssonCoordinatesFeat = ex.GetCarlssonCoordinatesFeature(pds)
persLifespanFeat = ex.GetPersLifespanFeature(pds)
# Out:
# C:\Users\Code\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# C:\Users\Code\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
